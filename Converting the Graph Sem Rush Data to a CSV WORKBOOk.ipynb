# %%
import os
# os.chdir("C:\\Users\\asus\\OneDrive\\Pictures")

# %%
path = "C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV"
directory = os.listdir(path)
count =0 
list=[]
for i in directory:
    count=count+1
    list.append(i)
list = sorted(list)

# %%
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\SEM RUSH SCRAPING\\Competitors_Matching.csv")

# %%
df = pd.DataFrame(df)
df
# Out:
#                    Name
# 0     101greatgoals.com
# 1        13.228.224.245
# 2        13.232.195.216
# 3         15.235.82.113
# 4       24tutorials.com
# ...                 ...
# 1504       zoominfo.com
# 1505          zudio.com
# 1506        zunroof.com
# 1507          zvolv.com
# 1508        zyusedu.com
#
# [1509 rows x 1 columns]

# %%
len(list)
# Out:
# 1469

# %%
print(len(list))
# Out:
# 1469

# %%
print(list)
# Out:
# ['101greatgoals_com.xlsx', '13_228_224_245.xlsx', '13_232_195_216.xlsx', '15_235_82_113.xlsx', '24tutorials_com.xlsx', '35_154_254_159.xlsx', '3_7_119_125.xlsx', '3veta_com.xlsx', '4tigo_com.xlsx', '97_107_129_104.xlsx', '99corporates_com.xlsx', 'aaad_in.xlsx', 'abbreviations_com.xlsx', 'abgsustainability_com.xlsx', 'abhihaara_com.xlsx', 'absolutebarbecues_com.xlsx', 'absolutebarbecuesme_com.xlsx', 'accel_com.xlsx', 'accel_org.xlsx', 'accelbyte_io.xlsx', 'accellearning_com.xlsx', 'accelpractice_com.xlsx', 'accelwealthmanagement_com.xlsx', 'accessfintech_com.xlsx', 'acpdc_in.xlsx', 'adda247_com.xlsx', 'adda52_com.xlsx', 'addresshome_com.xlsx', 'adequateinfosoft_com.xlsx', 'adityabirlahealth_com.xlsx', 'adityabirlawealthmanagement_com.xlsx', 'admitkard_com.xlsx', 'adonmo_com.xlsx', 'adpushup_com.xlsx', 'advance_ai.xlsx', 'aeccglobal_in.xlsx', 'aegte_in.xlsx', 'aesthetictoday_com.xlsx', 'agoria_be.xlsx', 'agri-service_com.xlsx', 'agribolo_com.xlsx', 'agrocentro_com.xlsx', 'agrochemicali
# ...

# %%
list = sorted(list)
import numpy as np

array =np.array(list)

# %%
len(list)
# Out:
# 1469

# %%
for j in df["Name"]:
    j = j.replace(".","_")
    for i in list:
        i= i.strip(".xlsx")

# %%
df
# Out:
#                    Name
# 0     101greatgoals.com
# 1        13.228.224.245
# 2        13.232.195.216
# 3         15.235.82.113
# 4       24tutorials.com
# ...                 ...
# 1504       zoominfo.com
# 1505          zudio.com
# 1506        zunroof.com
# 1507          zvolv.com
# 1508        zyusedu.com
#
# [1509 rows x 1 columns]

# %%
df= np.array(df)

# %%
df = df.flatten()

# %%
df = np.array(df)

# %%
lendf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <module>
# ----> 1 lendf
#
# NameError: name 'lendf' is not defined

# %%
set_df = set(df)

# %%
len(set_df)
# Out:
# 1469

# %%
set_df = sorted(set_df)

# %%
set_my_list = set(list)

# %%
set_my_list = sorted(set_my_list)

# %%
len(set_my_list)
# Out:
# 1469

# %%
competitors = pd.read_excel("C:\\Users\\asus\\OneDrive\\Desktop\\SEM RUSH SCRAPING\\Competitor_Final_xl.xlsx")

# %%
competitors
# Out:
#                      Main          Competitor 1            Competitor 2  \
# 0               sarva.com            sarva.live            divayoga.com
# 1             velocity.in        hellomeets.com  indianangelnetwork.com
# 2        indiafilings.com       vakilsearch.com              taxguru.in
# 3               leap.club           leap365.com           wexhealth.com
# 4    bugworksresearch.com            carb-x.org            ignitelsf.in
# ..                    ...                   ...                     ...
# 605         easyfi.net.in         ditscentre.in          mmcinternet.in
# 606              tilla.in          tillashop.in              pastau.com
# 607     vidyarobotics.com  innovativeeideas.com            elprocus.com
# 608         madstudios.in            mad.studio                mad.film
# 609      letsednovate.com           ednovate.in            ednovate.org
#
#                  Competitor 3                             Competitor 4  \
# ...

# %%
comp_df = pd.DataFrame(competitors)
comp_df
# Out:
#                      Main          Competitor 1            Competitor 2  \
# 0               sarva.com            sarva.live            divayoga.com
# 1             velocity.in        hellomeets.com  indianangelnetwork.com
# 2        indiafilings.com       vakilsearch.com              taxguru.in
# 3               leap.club           leap365.com           wexhealth.com
# 4    bugworksresearch.com            carb-x.org            ignitelsf.in
# ..                    ...                   ...                     ...
# 605         easyfi.net.in         ditscentre.in          mmcinternet.in
# 606              tilla.in          tillashop.in              pastau.com
# 607     vidyarobotics.com  innovativeeideas.com            elprocus.com
# 608         madstudios.in            mad.studio                mad.film
# 609      letsednovate.com           ednovate.in            ednovate.org
#
#                  Competitor 3                             Competitor 4  \
# ...

# %%
comp_df = comp_df[637:640]

main_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <module>
#       1 comp_df = comp_df[637:640]
# ----> 3 main_df
#
# NameError: name 'main_df' is not defined

# %%
os.chdir("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH SAMPLE FINAL DATA FRAMES")
for i, j in comp_df.iterrows():
    try:
        main = j[0]
        comp1 = j[1]
        comp2 = j[2]
        comp3 = j[3]
        comp4= j [4]
        comp5 = j[5]

        main = main.replace(".","_")
        comp1= comp1.replace(".","_")
        comp2 = comp2.replace(".","_")
        comp3=comp3.replace(".","_")
        comp4=comp4.replace(".","_")
        comp5=comp5.replace(".","_")

        main_df= pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(main))
        comp1_df = pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(comp1))
        comp2_df = pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(comp2))    
        comp3_df = pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(comp3))    
        comp4_df = pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(comp4))    
        comp5_df = pd.read_excel("C:\\Users\\asus\\OneDrive\\Documents\\SEM RUSH GRAPHS SCRAPED CSV\\%s.xlsx"%(comp5))        

        main_df  = pd.DataFrame(main_df)
        comp1_df = pd.DataFrame(comp1_df) 
        comp2_df = pd.DataFrame(comp2_df)
        comp3_df = pd.DataFrame(comp3_df) 
        comp4_df = pd.DataFrame(comp4_df)
        comp5_df = pd.DataFrame(comp5_df)

        main_df =  main_df.drop([1,2,3,4,5])
        comp1_df = comp1_df.drop([1,2,3,4,5])
        comp2_df = comp2_df.drop([1,2,3,4,5])
        comp3_df = comp3_df.drop([1,2,3,4,5])
        comp4_df = comp4_df.drop([1,2,3,4,5])
        comp5_df = comp5_df.drop([1,2,3,4,5])

        final_df=pd.concat([main_df,comp1_df,comp2_df,comp3_df,comp4_df,comp5_df],axis = 0)
        final_df.to_csv("%s.csv"%(main))
    except:
        pass
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
main_df
# Out:
#                     Target  Target Type           Metric Database  Summary  \
# 0  orangeretailfinance.com  root domain  Organic Traffic       in   134017
#
#    2015-06  2015-07  2015-08  2015-09  2015-10  ...  2022-04  2022-05  \
# 0        4        4        4        8        9  ...     3900     3887
#
#    2022-06  2022-07  2022-08  2022-09  2022-10  2022-11  2022-12  2023-01
# 0     3899     3871     3867     4344     4681     4482     4794     4740
#
# [1 rows x 97 columns]

# %%
import pandas as pd
import numpy as np
import os

# %%
list_to_be_obtained = pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\SEM RUSH SCRAPING\\TOTALTILLCOE_IOT.csv")

# %%
list_to_be_obtained.duplicates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <module>
# ----> 1 list_to_be_obtained.duplicates
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
final_df = final_df.drop(["Target Type"],axis=1)
final_df
