# %%
import pandas as pd
import numpy as np
import os

# %%
path = "C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\Mobile Data Sets\\mobile data\\"

# %%
os.listdir(path)
# Out:
# ['100ms_live.xlsx',
#  '13_233_63_207.xlsx',
#  '183_82_97_1.xlsx',
#  '1kproject_org.xlsx',
#  '2gudindia_com.xlsx',
#  '2hrsdelivery_in.xlsx',
#  '315workavenue_com.xlsx',
#  '32watts_com.xlsx',
#  '5cnetwork_com.xlsx',
#  '5gtechindia_in.xlsx',
#  '60secondsnow_com.xlsx',
#  '925silverjaipur_com.xlsx',
#  'a-z-animals_com.xlsx',
#  'aagrahfoods_com.xlsx',
#  'aaha_org.xlsx',
#  'aahilyaproperty_com.xlsx',
#  'abcconsultants_in.xlsx',
#  'abnd_in.xlsx',
#  'abodeboutiquehotels_com.xlsx',
#  'about-payments_com.xlsx',
#  'academicschoice_com.xlsx',
#  'accion_org.xlsx',
#  'accu-chek_com.xlsx',
#  'accusureindia_com.xlsx',
#  'acharyashunya_com.xlsx',
#  'acpdc_in.xlsx',
#  'acptechnologies_com.xlsx',
#  'activebrainacademy_ch.xlsx',
#  'active_com.xlsx',
#  'adivedanatural_com.xlsx',
#  'admitkard_com.xlsx',
#  'adonmo_com.xlsx',
#  'advisorkhoj_com.xlsx',
#  'aestheticabeautycenter_it.xlsx',
#  'aevantenterprises_in.xlsx',
#  'afcurgentcare_com.xlsx',
#  'afpllive_com.xlsx',
# ...

# %%
for filename in os.listdir("C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\.com files"):
    data = pd.read_excel("C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\.com files\\"+filename,index_col=0)
    data = data.drop_duplicates()
    data.to_excel("C:\\Users\\asus\\Desktop\\New SEMRUSH CLEANED DATA\\.com files\\"+fname)
# len(os.listdir("C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\.com files")   )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <module>
#       2 data = pd.read_excel("C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\.com files\\"+filename,index_col=0)
#       3 data = data.drop_duplicates()
# ----> 4 data.to_excel("C:\\Users\\asus\\Desktop\\New SEMRUSH CLEANED DATA\\.com files\\"+fname)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2357, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2344 from pandas.io.formats.excel import ExcelFormatter
#    2346 formatter = ExcelFormatter(
#    2347     df,
#    2348     na_rep=na_rep,
#    (...)
#    2355     inf_rep=inf_rep,
#    2356 )
# -> 2357 formatter.write(
#    2358     excel_writer,
# ...

# %%
ex_data = "C:\\Users\\asus\\Desktop\\2gudindia_com.xlsx"

# %%
data = pd.read_excel(ex_data,index_col=0)
data = data.drop_duplicates()

# %%
data.drop_duplicates("Dates",inplace =True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 data.drop_duplicates("Dates",inplace =True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6110, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6108 inplace = validate_bool_kwarg(inplace, "inplace")
#    6109 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# ...

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#     Unnamed: 0            Date Organic Trafic  Paid Traffic
# 0            0      April 2017              0             0
# 1            1        May 2017              0             0
# 2            2       June 2017              0             0
# 3            3       July 2017              0             0
# 4            4       July 2017              0             0
# ..         ...             ...            ...           ...
# 84          84  September 2022              0             0
# 85          85    October 2022              0             0
# 86          86   November 2022              0             0
# 87          87   December 2022          2,070             0
# 88          88   December 2022          2,070             0
#
# [89 rows x 4 columns]

# %%
path2 = "C:\\Users\\asus\\Desktop\\SEMRUSH FULL DATA\\.com files\\"
for filename in os.listdir(path2):
    data = pd.read_excel(path2+filename,index_col=0)
    data = data.drop_duplicates()
    data.to_excel("C:\\Users\\asus\\Desktop\\New SEMRUSH CLEANED DATA\\other files\\"+filename)
