# %%
from bs4 import BeautifulSoup 
import requests 
import lxml
from selenium import webdriver
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
url ='https://www.semrush.com/analytics/overview/?q=https%3A%2F%2Fwww.swiggy.com%2F&searchType=domain'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text ,"lxml")

# %%
soup
# Out:
# <!-- sm_log_id: "flb-b28d698e261894811410d5ef51a03edb" --><!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="/__static__/fonts/factor_a/v2/factor_a.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Inter:slnt,wght@-10..0,100..900&amp;family=Ubuntu:wght@300;400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://google-analytics.bi.owox.com" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://adservice.google.com" rel="preconnect"/>
# <link href="https://alb.reddit.com" rel="preconnect"/>
# <link href="https://analytics.twitter.com" rel="preconnect"/>
# <link href="https://api.mindbox.cloud" rel="preconnect"/>
# ...

# %%
driver  = webdriver.Chrome('C:\\Users\\asus\\OneDrive\\Desktop\\Drivers\\chromedriver.exe')
driver.get('https://www.semrush.com/analytics/organic/competitors/?sortField=&sortDirection=desc&db=us&q=swiggy.com&searchType=domain')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_20512\1574280540.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver  = webdriver.Chrome('C:\\Users\\asus\\OneDrive\\Desktop\\Drivers\\chromedriver.exe')

# %%
driver.find_element(by ='xpath',value='//*[@id="domain-overview-app"]/div/div[2]/div[2]/div[1]/div/div[1]/div[1]/div[2]/div[1]/div[2]/a/span').text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 driver.find_element(by ='xpath',value='//*[@id="domain-overview-app"]/div/div[2]/div[2]/div[1]/div/div[1]/div[1]/div[2]/div[1]/div[2]/a/span').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %%
driver.find_element(by ='xpath',value='//*[@id="domain-overview-app"]/div/div[2]/div[2]/div[1]/div/div[1]/div[2]/div[2]/div[1]/a/span').text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 driver.find_element(by ='xpath',value='//*[@id="domain-overview-app"]/div/div[2]/div[2]/div[1]/div/div[1]/div[2]/div[2]/div[1]/a/span').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %%
url ='https://www.semrush.com/analytics/organic/competitors/?sortField=&sortDirection=desc&db=us&q=swiggy.com&searchType=domain'
page = requests.get(url)
soup = BeautifulSoup(page.text,'lxml')

# %%
import pandas as pd
list=[]
for i in range (1,100):
    list.append(driver.find_element(by ='xpath' ,value ='//*[@id="cl-competitors-table"]/div[2]/div/div/div/div/div['+str(i)+']').text)

# %%
for i in list:
    i.split('\n')
    print(i)
# Out:
# restaurant-guru.in
# 34%
# 2.1K
# 53.7K
# 4.5K
# 1.3K
# 0
# magicpin.in
# 30%
# 3.8K
# 182.4K
# 29.1K
# 15.5K
# 0
# dineout.co.in
# 24%
# 1.5K
# 34.5K
# 14.8K
# 10.8K
# 0
# eazydiner.com
# 22%
# 1.4K
# 38.3K
# 10.2K
# 10.4K
# 0
# nearbuy.com
# 14%
# 676
# 19.7K
# 3.1K
# 1.8K
# 0
# lbb.in
# 12%
# 1.1K
# 79.7K
# 22.4K
# 18.2K
# 0
# sluurpy.in
# 10%
# 484
# 12.5K
# 401
# 58
# 0
# indiapl.com
# 7%
# 475
# 41.3K
# 5K
# 789
# 0
# justdial.com
# 5%
# 3.7K
# 1.1M
# 177.8K
# 89.9K
# 0
# whatshot.in
# 5%
# 257
# 18.8K
# 2.5K
# 824
# 0
# mappls.com
# 5%
# 287
# 35.3K
# 3.7K
# 2.2K
# 0
# bigbasket.com
# 5%
# 367
# 105.6K
# 23.5K
# 22.9K
# 6
# mapmyindia.com
# 5%
# 214
# 22.7K
# 1.4K
# 787
# 0
# dunzo.com
# 4%
# 158
# 4.5K
# 4.3K
# 10.1K
# 0
# mouthshut.com
# 4%
# 502
# 124.7K
# 33.4K
# 53.4K
# 0
# bharatibiz.com
# 4%
# 218
# 42.2K
# 1.5K
# 503
# 0
# so.city
# 3%
# 132
# 18.8K
# 6.1K
# 4.3K
# 0
# dominos.co.in
# 2%
# 96
# 8K
# 7.7K
# 2.9K
# 4
# heyplaces.in
# 2%
# 85
# 4.8K
# 455
# 26
# 0
# ...

# %%
df= pd.DataFrame({'company name':[''],'.com level':[''],'traffic':['']})
for i in range(1,100):
    comp_name = driver.find_element(by ='xpath',value ='//*[@id="cl-competitors-table"]/div[2]/div/div/div/div/div['+str(i)+']/div[1]').text
    com_level =driver.find_element(by ='xpath',value  ='//*[@id="cl-competitors-table"]/div[2]/div/div/div/div/div['+str(i)+']/div[2]').text
    traffic =driver.find_element(by ='xpath',value ='//*[@id="cl-competitors-table"]/div[2]/div/div/div/div/div['+str(i)+']/div[5]').text
    length = len(df)
    df.loc[length] ={'company name':comp_name,'.com level':com_level,'traffic':traffic}

# %%
for i in range(1,10):
    print(driver.find_element(by='xpath',value='//*[@id="non-existing-id"]/table/tbody/tr['+str(i)+']').text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [13], in <module>
#       1 for i in range(1,10):
# ----> 2     print(driver.find_element(by='xpath',value='//*[@id="non-existing-id"]/table/tbody/tr['+str(i)+']').text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %%
import os 
import requests
url ='https://www.semrush.com/notes/api/notes/v2/notes/?per_page=1000&locale=en&datetime_from=2020-12-31T18%3A30%3A00.000Z&page=1&ordering=-datetime%2C-created&tools=DOMAIN_OVERVIEW&databases=US%2CALL'
proxies = {}
response = requests.get(url=url,proxies=proxies)
with open('response.csv' ,'wb') as f:
    f.write(response.content)

# %%
os.chdir('C:\\Users\\asus\\OneDrive\\Desktop\\UDEMY_DATA_SCRAPING_CHRISTOPHER_ZITA')
